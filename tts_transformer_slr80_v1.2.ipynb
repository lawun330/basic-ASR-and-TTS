# %% [markdown]
# # TTS Tutorial Remake with SLR80 Dataset
#
# ## Original
# - **Prepared by:** Ye Kyaw Thu, Language Understanding Lab., Myanmar
# - **Last Updated Date:** 20 June 2026
# - **Reason:** *For AI Engineering (Fundamental) class students*
#
# ## Remake: Experiment Version 1.2
# This remake follows the same tutorial flow with v6, which adds HiFi-GAN/WaveGlow vocoders, scheduled sampling, softer stop, and attention plots on top of the v5 TransformerTTS core.

# %% [markdown]
# ## Setup

# %%
from pathlib import Path

current_dir = Path.cwd()
SCRIPTS = current_dir / "scripts"
SRC = current_dir / "src"

# %% [markdown]
# ## Download Dataset: SLR80

# %%
# skip if data already downloaded
# !time {SCRIPTS}/download_dataset.sh

# %%
# !tree ./data/ | head -n 10
# Out:
# ./data/
# └── slr80
#     ├── bur_0366_0045318711.wav
#     ├── bur_0366_0096392289.wav
#     ├── bur_0366_0178258874.wav
#     ├── bur_0366_0235517782.wav
#     ├── bur_0366_0432235369.wav
#     ├── bur_0366_0445549145.wav
#     ├── bur_0366_0446483510.wav
#     ├── bur_0366_0469985799.wav

# %%
# !head ./data/slr80/line_index_female.tsv
# Out:
# bur_7865_1250917969	ပြီးတော့ တရုတ် နဲ့လည်း ချစ်ကြည်ရင်းနှီးတဲ့ ဆက်ဆံရေး ရှိတယ်
# bur_8698_6883351313	အဲ့ဒီ ဝေဖန်မှုတွေ နဲ့ ပတ်သက် လို့ ဘယ်လို တုံ့ပြန်ချင်ပါသလဲ
# bur_3260_8853590661	မမီ မွေးဖွားနေတဲ့ အချိန် မှာတော့ ဘုရား ဂုဏ်တော် ကိုပဲ တောက်လျှောက် ရွတ်နေခဲ့ပါတယ်
# bur_2446_1980151079	ခင်ဦးသာ နှင့် နန်းလွင်နှင်းပွင့် ပူးပေါင်း ရေးသားသည်
# bur_5189_8958061789	ကြည့်ရသည်မှာ မြန်မာ နိုင်ငံ တွင် သူ့ အတွက် ခိုလှုံရာ တခု တွေ့ခဲ့ပုံ ရပါသည်
# bur_6884_6350507293	မမဖွေးဖွေး နဲ့ တွေ့ရ တော့ တအား ပျော်တယ် လို့ ပြောပါတယ်
# bur_5362_7563127136	အထူးသဖြင့် နိုင်ငံရေး လောက ကို စုစည်းနိုင်ခဲ့သည် ဟု ဆိုနိုင်ပါသည်
# bur_7543_6156096513	ကဖင်း မပါဝင်သော ကော်ဖီ သောက်ပါ
# bur_8266_0671510151	ကောလင်း မြို့နယ် ရေကြီးတာ က ဆည်ကျိုး လို့ မဟုတ်ဘူး
# bur_6118_8081481703	ကျွန်မ အလုပ် ကို လေးလေးစားစား လုပ်ပါတယ်

# %%
# !head ./data/slr80/line_index.tsv
# Out:
# bur_7865_1250917969	ပြီးတော့ တရုတ် နဲ့လည်း ချစ်ကြည်ရင်းနှီးတဲ့ ဆက်ဆံရေး ရှိတယ်
# bur_8698_6883351313	အဲ့ဒီ ဝေဖန်မှုတွေ နဲ့ ပတ်သက် လို့ ဘယ်လို တုံ့ပြန်ချင်ပါသလဲ
# bur_3260_8853590661	မမီ မွေးဖွားနေတဲ့ အချိန် မှာတော့ ဘုရား ဂုဏ်တော် ကိုပဲ တောက်လျှောက် ရွတ်နေခဲ့ပါတယ်
# bur_2446_1980151079	ခင်ဦးသာ နှင့် နန်းလွင်နှင်းပွင့် ပူးပေါင်း ရေးသားသည်
# bur_5189_8958061789	ကြည့်ရသည်မှာ မြန်မာ နိုင်ငံ တွင် သူ့ အတွက် ခိုလှုံရာ တခု တွေ့ခဲ့ပုံ ရပါသည်
# bur_6884_6350507293	မမဖွေးဖွေး နဲ့ တွေ့ရ တော့ တအား ပျော်တယ် လို့ ပြောပါတယ်
# bur_5362_7563127136	အထူးသဖြင့် နိုင်ငံရေး လောက ကို စုစည်းနိုင်ခဲ့သည် ဟု ဆိုနိုင်ပါသည်
# bur_7543_6156096513	ကဖင်း မပါဝင်သော ကော်ဖီ သောက်ပါ
# bur_8266_0671510151	ကောလင်း မြို့နယ် ရေကြီးတာ က ဆည်ကျိုး လို့ မဟုတ်ဘူး
# bur_6118_8081481703	ကျွန်မ အလုပ် ကို လေးလေးစားစား လုပ်ပါတယ်

# %% [markdown]
# ## Prepare Dataset: SLR80
#
# Original:
# ```Python
# !time python {SRC}/myanmar_tts_transformer.py --stage prep \
#   --data_dir ./data/slr80 \
#   --output_dir ./tts_output
# ```
#
# NAR version:
# ```Python
# !time python {SRC}/myanmar_tts_transformer_nar.py --stage prep \
#   --data_dir ./data/slr80 \
#   --output_dir ./tts_output/nar_version
# ```

# %%
# !time python {SRC}/myanmar_tts_transformer_v6.py --stage prep \
  --data_dir ./data/slr80 \
  --output_dir "./tts_output/v6_exp_1.2"
# Out:
# 2026-09-24 16:53:25  [INFO    ]  Found 2530 audio files.
# 2026-09-24 16:53:25  [INFO    ]  Vocabulary: 66 characters
# 2026-09-24 16:53:25  [INFO    ]  Computing mel spectrograms ...
# 2026-09-24 16:53:34  [INFO    ]    500/2530 ...
# 2026-09-24 16:53:42  [INFO    ]    1000/2530 ...
# 2026-09-24 16:53:49  [INFO    ]    1500/2530 ...
# 2026-09-24 16:53:58  [INFO    ]    2000/2530 ...
# 2026-09-24 16:54:08  [INFO    ]    2500/2530 ...
# 2026-09-24 16:54:08  [INFO    ]  Valid: 2530 | Skipped: 0
# 2026-09-24 16:54:08  [INFO    ]  Mel norm check: min=-1.000 max=1.000 mean=-0.481
# 2026-09-24 16:54:08  [INFO    ]  Mel frames : mean=504 ± 150
# 2026-09-24 16:54:08  [INFO    ]  Frames/char: mean=7.3 ± 1.6
# 2026-09-24 16:54:08  [INFO    ]    train: 2024
# 2026-09-24 16:54:08  [INFO    ]    dev: 253
# 2026-09-24 16:54:08  [INFO    ]    test: 253
# 2026-09-24 16:54:08  [INFO    ]  Data preparation complete ✓
#
# real	0m45.994s
# user	7m57.131s
# sys	0m1.800s

# %% [markdown]
# ## Model Training
#
# Original:
# ```Python
# !time python {SRC}/myanmar_tts_transformer.py --stage train \
#   --output_dir ./tts_output \
#   --epochs 300
# ```
#
# NAR version:
# ```Python
# !time python {SRC}/myanmar_tts_transformer_nar.py --stage train \
#   --output_dir ./tts_output/nar_version \
#   --epochs 300 \
#   --batch_size 8 \
#   --dur_loss_weight 1.0
# ```
#
# v6 experiment 1.0 version:
# ```python
# !time python {SRC}/myanmar_tts_transformer_v6.py --stage train \
#   --output_dir ./tts_output/v6 \
#   --epochs 300 \
#   --batch_size 8 \
#   --ga_weight 1.0 --ga_g 0.2 \
#   --ss_start_epoch 50 \
#   --ss_max_prob 0.5
# ```
#
# v6 experiment 1.1 version:
# ```python
# !time python {SRC}/myanmar_tts_transformer_v6.py --stage train \
#   --output_dir "./tts_output/v6_exp_1.1" \
#   --epochs 130 \
#   --batch_size 8 \
#   --ga_weight 3.0 --ga_g 0.15 \
#   --ss_start_epoch 20 \
#   --ss_max_prob 0.8
# ```

# %%
# !time python {SRC}/myanmar_tts_transformer_v6.py --stage train \
  --output_dir "./tts_output/v6_exp_1.2" \
  --epochs 50 \
  --batch_size 8 \
  --ga_weight 5.0 --ga_g 0.1 \
  --ss_start_epoch 10 \
  --ss_max_prob 0.8
# Out:
# 2026-09-24 16:54:34  [INFO    ]  Vocab:66  Train:2024  Dev:253
# 2026-09-24 16:54:34  [INFO    ]  Device: cuda
# 2026-09-24 16:54:35  [INFO    ]  TransformerTTS parameters: 45,399,617
# 2026-09-24 16:54:37  [INFO    ]  Training 50 epochs (warmup=20, lr=1.0e-03)
# 2026-09-24 16:54:37  [INFO    ]  Architecture: TransformerTTS v6 + Guided Attention + HiFi-GAN
# 2026-09-24 16:54:37  [INFO    ]    ga_weight=5.0  ga_g=0.1  stop_loss_weight=0.1
# 2026-09-24 16:54:37  [INFO    ]    scheduled sampling: start_epoch=10  max_prob=0.8
# 2026-09-24 16:54:37  [INFO    ]  Expected: dig should fall toward ~0.2–0.4 like v5 if GA is healthy.
# 2026-09-24 16:57:58  [INFO    ]  Epoch    1/50 | train=1.6559  dev=0.9193 | lr=1.00e-04  ss=0.00
# 2026-09-24 16:57:58  [INFO    ]    ✓ Best model saved (dev=0.9193)
# 2026-09-24 17:01:31  [INFO    ]  Epoch    2/50 | train=1.1119  dev=0.8195 | lr=1.50e-04  ss=0.00
# 2026-09-24 17:01:38  [INFO    ]    ✓ Best model saved (dev=0.8195)
# 2026-09-24 17:05:36  [INFO    ]  Epoch    3/50 | train=0.9207  dev=0.7178 | lr=2.00e-04  ss=0.00
# 2026-09-24 17:05:45  [INFO    ]    ✓ Best model saved (dev=0.7178)
# 2026-09-24 17:09:57  [INFO    ]  Epoch    4/50 | train=0.7950  dev=0.6829 | lr=2.50e-04  ss=0.00
# 2026-09-24 17:10:02  [INFO    ]    ✓ Best model saved (dev=0.6829)
# 2026-09-24 17:14:17  [INFO    ]  Epoch    5/50 | train=0.8630  dev=0.6778 | lr=3.00e-04  ss=0.00
# 2026-09-24 17:14:23  [INFO    ]    ✓ Best model saved (dev=0.6778)
# 2026-09-24 17:18:21  [INFO    ]  Epoch    6/50 | train=0.7362  dev=0.5936 | lr=3.50e-04  ss=0.00
# 2026-09-24 17:18:22  [INFO    ]    ✓ Best model saved (dev=0.5936)
# 2026-09-24 17:21:50  [INFO    ]  Epoch    7/50 | train=0.6635  dev=0.5567 | lr=4.00e-04  ss=0.00
# 2026-09-24 17:21:51  [INFO    ]    ✓ Best model saved (dev=0.5567)
# 2026-09-24 17:25:18  [INFO    ]  Epoch    8/50 | train=0.6220  dev=0.5246 | lr=4.50e-04  ss=0.00
# 2026-09-24 17:25:19  [INFO    ]    ✓ Best model saved (dev=0.5246)
# 2026-09-24 17:28:42  [INFO    ]  Epoch    9/50 | train=0.6010  dev=0.5218 | lr=5.00e-04  ss=0.00
# 2026-09-24 17:28:43  [INFO    ]    ✓ Best model saved (dev=0.5218)
# 2026-09-24 17:33:10  [INFO    ]  Epoch   10/50 | train=0.5563  dev=0.4882 | lr=5.50e-04  ss=0.02
# 2026-09-24 17:33:11  [INFO    ]    ✓ Best model saved (dev=0.4882)
# 2026-09-24 17:37:34  [INFO    ]  Epoch   11/50 | train=0.4843  dev=0.4556 | lr=6.00e-04  ss=0.04
# 2026-09-24 17:37:43  [INFO    ]    ✓ Best model saved (dev=0.4556)
# 2026-09-24 17:42:03  [INFO    ]  Epoch   12/50 | train=0.4543  dev=0.4257 | lr=6.50e-04  ss=0.06
# 2026-09-24 17:42:09  [INFO    ]    ✓ Best model saved (dev=0.4257)
# 2026-09-24 17:46:30  [INFO    ]  Epoch   13/50 | train=0.4365  dev=0.4132 | lr=7.00e-04  ss=0.08
# 2026-09-24 17:46:37  [INFO    ]    ✓ Best model saved (dev=0.4132)
# 2026-09-24 17:51:01  [INFO    ]  Epoch   14/50 | train=0.4301  dev=0.4079 | lr=7.50e-04  ss=0.10
# 2026-09-24 17:51:05  [INFO    ]    ✓ Best model saved (dev=0.4079)
# 2026-09-24 17:55:27  [INFO    ]  Epoch   15/50 | train=0.4181  dev=0.3935 | lr=8.00e-04  ss=0.12
# 2026-09-24 17:55:33  [INFO    ]    ✓ Best model saved (dev=0.3935)
# 2026-09-24 17:59:56  [INFO    ]  Epoch   16/50 | train=0.4122  dev=0.3983 | lr=8.50e-04  ss=0.14
# 2026-09-24 18:04:20  [INFO    ]  Epoch   17/50 | train=0.4043  dev=0.3840 | lr=9.00e-04  ss=0.16
# 2026-09-24 18:04:27  [INFO    ]    ✓ Best model saved (dev=0.3840)
# 2026-09-24 18:08:48  [INFO    ]  Epoch   18/50 | train=0.4052  dev=0.3831 | lr=9.50e-04  ss=0.18
# 2026-09-24 18:08:49  [INFO    ]    ✓ Best model saved (dev=0.3831)
# 2026-09-24 18:13:11  [INFO    ]  Epoch   19/50 | train=0.3985  dev=0.3780 | lr=1.00e-03  ss=0.20
# 2026-09-24 18:13:12  [INFO    ]    ✓ Best model saved (dev=0.3780)
# 2026-09-24 18:17:37  [INFO    ]  Epoch   20/50 | train=0.3939  dev=0.3699 | lr=1.00e-03  ss=0.22
# 2026-09-24 18:17:38  [INFO    ]    ✓ Best model saved (dev=0.3699)
# 2026-09-24 18:22:09  [INFO    ]  Epoch   21/50 | train=0.3916  dev=0.3651 | lr=9.97e-04  ss=0.24
# 2026-09-24 18:22:11  [INFO    ]    ✓ Best model saved (dev=0.3651)
# 2026-09-24 18:26:37  [INFO    ]  Epoch   22/50 | train=0.3858  dev=0.3687 | lr=9.90e-04  ss=0.26
# 2026-09-24 18:31:09  [INFO    ]  Epoch   23/50 | train=0.3818  dev=0.3635 | lr=9.77e-04  ss=0.28
# 2026-09-24 18:31:10  [INFO    ]    ✓ Best model saved (dev=0.3635)
# 2026-09-24 18:35:36  [INFO    ]  Epoch   24/50 | train=0.3795  dev=0.3510 | lr=9.59e-04  ss=0.30
# 2026-09-24 18:35:37  [INFO    ]    ✓ Best model saved (dev=0.3510)
# 2026-09-24 18:40:02  [INFO    ]  Epoch   25/50 | train=0.3748  dev=0.3459 | lr=9.36e-04  ss=0.32
# 2026-09-24 18:40:08  [INFO    ]    ✓ Best model saved (dev=0.3459)
# 2026-09-24 18:44:30  [INFO    ]  Epoch   26/50 | train=0.3745  dev=0.3427 | lr=9.09e-04  ss=0.34
# 2026-09-24 18:44:36  [INFO    ]    ✓ Best model saved (dev=0.3427)
# 2026-09-24 18:49:04  [INFO    ]  Epoch   27/50 | train=0.3684  dev=0.3446 | lr=8.78e-04  ss=0.36
# 2026-09-24 18:53:32  [INFO    ]  Epoch   28/50 | train=0.3654  dev=0.3356 | lr=8.43e-04  ss=0.38
# 2026-09-24 18:53:36  [INFO    ]    ✓ Best model saved (dev=0.3356)
# 2026-09-24 18:58:01  [INFO    ]  Epoch   29/50 | train=0.3617  dev=0.3396 | lr=8.04e-04  ss=0.40
# 2026-09-24 19:02:36  [INFO    ]  Epoch   30/50 | train=0.3591  dev=0.3347 | lr=7.62e-04  ss=0.42
# 2026-09-24 19:02:42  [INFO    ]    ✓ Best model saved (dev=0.3347)
# 2026-09-24 19:07:14  [INFO    ]  Epoch   31/50 | train=0.3563  dev=0.3331 | lr=7.18e-04  ss=0.44
# 2026-09-24 19:07:16  [INFO    ]    ✓ Best model saved (dev=0.3331)
# 2026-09-24 19:11:44  [INFO    ]  Epoch   32/50 | train=0.3538  dev=0.3287 | lr=6.72e-04  ss=0.46
# 2026-09-24 19:11:45  [INFO    ]    ✓ Best model saved (dev=0.3287)
# 2026-09-24 19:16:20  [INFO    ]  Epoch   33/50 | train=0.3523  dev=0.3235 | lr=6.24e-04  ss=0.48
# 2026-09-24 19:16:21  [INFO    ]    ✓ Best model saved (dev=0.3235)
# 2026-09-24 19:20:57  [INFO    ]  Epoch   34/50 | train=0.3490  dev=0.3251 | lr=5.75e-04  ss=0.50
# 2026-09-24 19:25:31  [INFO    ]  Epoch   35/50 | train=0.3473  dev=0.3220 | lr=5.25e-04  ss=0.52
# 2026-09-24 19:25:33  [INFO    ]    ✓ Best model saved (dev=0.3220)
# 2026-09-24 19:30:10  [INFO    ]  Epoch   36/50 | train=0.3445  dev=0.3211 | lr=4.75e-04  ss=0.54
# 2026-09-24 19:30:12  [INFO    ]    ✓ Best model saved (dev=0.3211)
# 2026-09-24 19:34:44  [INFO    ]  Epoch   37/50 | train=0.3425  dev=0.3190 | lr=4.26e-04  ss=0.56
# 2026-09-24 19:34:45  [INFO    ]    ✓ Best model saved (dev=0.3190)
# 2026-09-24 19:39:19  [INFO    ]  Epoch   38/50 | train=0.3397  dev=0.3167 | lr=3.78e-04  ss=0.58
# 2026-09-24 19:39:26  [INFO    ]    ✓ Best model saved (dev=0.3167)
# 2026-09-24 19:43:55  [INFO    ]  Epoch   39/50 | train=0.3379  dev=0.3147 | lr=3.32e-04  ss=0.60
# 2026-09-24 19:44:00  [INFO    ]    ✓ Best model saved (dev=0.3147)
# 2026-09-24 19:48:23  [INFO    ]  Epoch   40/50 | train=0.3359  dev=0.3147 | lr=2.88e-04  ss=0.62
# 2026-09-24 19:48:30  [INFO    ]    ✓ Best model saved (dev=0.3147)
# 2026-09-24 19:52:58  [INFO    ]  Epoch   41/50 | train=0.3343  dev=0.3121 | lr=2.46e-04  ss=0.64
# 2026-09-24 19:53:07  [INFO    ]    ✓ Best model saved (dev=0.3121)
# 2026-09-24 19:57:29  [INFO    ]  Epoch   42/50 | train=0.3329  dev=0.3107 | lr=2.07e-04  ss=0.66
# 2026-09-24 19:57:34  [INFO    ]    ✓ Best model saved (dev=0.3107)
# 2026-09-24 20:02:05  [INFO    ]  Epoch   43/50 | train=0.3316  dev=0.3107 | lr=1.72e-04  ss=0.68
# 2026-09-24 20:06:29  [INFO    ]  Epoch   44/50 | train=0.3304  dev=0.3103 | lr=1.41e-04  ss=0.70
# 2026-09-24 20:06:30  [INFO    ]    ✓ Best model saved (dev=0.3103)
# 2026-09-24 20:10:52  [INFO    ]  Epoch   45/50 | train=0.3293  dev=0.3088 | lr=1.14e-04  ss=0.72
# 2026-09-24 20:10:53  [INFO    ]    ✓ Best model saved (dev=0.3088)
# 2026-09-24 20:15:12  [INFO    ]  Epoch   46/50 | train=0.3297  dev=0.3087 | lr=9.11e-05  ss=0.74
# 2026-09-24 20:15:13  [INFO    ]    ✓ Best model saved (dev=0.3087)
# 2026-09-24 20:19:32  [INFO    ]  Epoch   47/50 | train=0.3284  dev=0.3079 | lr=7.32e-05  ss=0.76
# 2026-09-24 20:19:33  [INFO    ]    ✓ Best model saved (dev=0.3079)
# 2026-09-24 20:23:53  [INFO    ]  Epoch   48/50 | train=0.3282  dev=0.3077 | lr=6.04e-05  ss=0.78
# 2026-09-24 20:23:54  [INFO    ]    ✓ Best model saved (dev=0.3077)
# 2026-09-24 20:28:17  [INFO    ]  Epoch   49/50 | train=0.3285  dev=0.3078 | lr=5.26e-05  ss=0.80
# 2026-09-24 20:32:38  [INFO    ]  Epoch   50/50 | train=0.3276  dev=0.3079 | lr=5.00e-05  ss=0.80
# 2026-09-24 20:32:39  [INFO    ]  Training done. Best dev: 0.3077
#
# real	218m7.486s
# user	216m34.028s
# sys	1m36.198s

# %% [markdown]
# ## Check Samples

# %%
# !time python {SRC}/myanmar_tts_transformer_v6.py --stage synth \
  --output_dir "./tts_output/v6_exp_1.2" \
  --list_samples
# Out:
# /home/lawun330/.cache/torch/hub/NVIDIA_DeepLearningExamples_torchhub/PyTorch/Classification/ConvNets/image_classification/models/common.py:13: UserWarning: pytorch_quantization module not found, quantization will not be available
#   warnings.warn(
# /home/lawun330/.cache/torch/hub/NVIDIA_DeepLearningExamples_torchhub/PyTorch/Classification/ConvNets/image_classification/models/efficientnet.py:17: UserWarning: pytorch_quantization module not found, quantization will not be available
#   warnings.warn(
# /home/lawun330/anaconda3/envs/lu_aief_asr_tts_env/lib/python3.12/site-packages/torch/nn/utils/weight_norm.py:145: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)
# HiFi-GAN: Removing weight norm.
# 2026-09-24 20:59:07  [INFO    ]  HiFi-GAN loaded ✓  (NVIDIA torch.hub)
# 2026-09-24 20:59:07  [INFO    ]  Sample IDs (first 20):
# 2026-09-24 20:59:08  [INFO    ]    bur_8266_7413365509               ဥပမာ မိုးဟေကို ဆိုရင် ဆောင်းဟေကို နာမည် ကို ဆင်တူ
# 2026-09-24 20:59:08  [INFO    ]    bur_7865_2573585785               ဒါပေမဲ့ ဒီ ကျောက် က ရာသက်ပန် မကုန်အောင် ထွက်နေမှာ
# 2026-09-24 20:59:08  [INFO    ]    bur_5189_3215659791               ကိုကျော်သူ မမေသန်းနု ဒေါ်အေးအေးသင်းတို့ ပါတယ်
# 2026-09-24 20:59:08  [INFO    ]    bur_0644_5980380162               အမှန်တော့ မှတ်တမ်း ကို ဖလင် နဲ့ ရိုက် ပြီး ပြတဲ့ ရ
# 2026-09-24 20:59:08  [INFO    ]    bur_5932_9903725735               ကျနော် က ကျော်ထွဋ်ဆွေတို့ ဂျောက်ဂျက်တို့ နဲ့တော့ သ
# 2026-09-24 20:59:08  [INFO    ]    bur_5932_6467856225               ရုပ်ရှင်ကားကြီးတွေ ရိုက်ရင် ဖလင် က တအား ကုန်တယ်
# 2026-09-24 20:59:08  [INFO    ]    bur_7543_1589569333               ကာတွန်း ရှိန်အောင် ကို ပုသိမ်မြို့ မှာ အဖ ဦးမောင်က
# 2026-09-24 20:59:08  [INFO    ]    bur_9762_6350280557               ကြည့်ချင်တယ် ဆိုရင်လည်း ခရီးစဉ် တခါတည်း ထည့် ဆွဲထာ
# 2026-09-24 20:59:08  [INFO    ]    bur_5903_4827254748               အခု က ဖုန်း တစ်လုံး ပဲ ထားရတော့တယ် ဟု ဆိုသည်
# 2026-09-24 20:59:08  [INFO    ]    bur_3260_5647990176               ကိုယ် ကလည်း အချိန် မပေးနိုင်ဘူး ဆိုတော့ ဆရာဝန်ကြီး
# 2026-09-24 20:59:08  [INFO    ]    bur_5362_4730425798               ခေတ်မှီချင်သူတွေ ကတော့ ရေခဲမုန့် ကျွေးကြတာပေါ့
# 2026-09-24 20:59:08  [INFO    ]    bur_8266_3739445651               ကဲ အခု တော့ ဘယ့်နှယ့် ရှိစ
# 2026-09-24 20:59:08  [INFO    ]    bur_9135_9365873650               အထက် မြန်မာပြည် မန္တလေး မြို့ ၌လည်း ဘတ်စကတ်ဘော ကလပ
# 2026-09-24 20:59:08  [INFO    ]    bur_5932_0137380639               အရင် တုန်းကတော့ ဒီ ကိစ္စ ကို အားလုံး လေးငါးခြောက်ယ
# 2026-09-24 20:59:08  [INFO    ]    bur_8698_8976831996               မင်း အမေ ကို ကောင်းကောင်း ဆော်သွား လို့ မင်း ထွက်လ
# 2026-09-24 20:59:08  [INFO    ]    bur_0366_2701213104               ကမ္ဘာအနှံ့ မှ သတင်း အချက်အလက်တွေ ကို သိနိုင်သည်
# 2026-09-24 20:59:08  [INFO    ]    bur_0644_2661360424               ဆိုနီ ကရော ဘယ်လိုတွေ ချပြမလဲ လေ့လာကြည့်ရအောင်
# 2026-09-24 20:59:08  [INFO    ]    bur_7712_5029179191               ကမ္မောဇ ဘောလုံး အသင်း က ဥက္ကဌ ဦးခင်မောင်လတ် က အရင်
# 2026-09-24 20:59:08  [INFO    ]    bur_5362_4875790905               ကျွန်တော် ကလည်း ဒိတ်ဒိတ်ကျဲ အောင်မြင်နေတဲ့ မင်းသား
# 2026-09-24 20:59:08  [INFO    ]    bur_3260_2712519099               ကျနော် က ရိက္ခာ ယူခိုင်း တုန်း ထွက်ပြေးလာတာပါ
#
# real	0m6.109s
# user	0m14.357s
# sys	0m0.826s

# %% [markdown]
# ## Check Vocoders
#
# Install Myanmar font via:
# ```bash
# sudo apt update
# sudo apt install python3-gi python3-gi-cairo gir1.2-pango-1.0
#
# # alternatively
# sudo apt install fonts-sil-padauk fonts-noto-core
# ```

# %% [markdown]
# ### Example Sample 1 - HiFi-GAN

# %%
# !time python {SRC}/myanmar_tts_transformer_v6.py --stage synth \
  --output_dir "./tts_output/v6_exp_1.2" \
  --gt_sample_id bur_5362_4875790905 \
  --synth_out "./tts_output/v6_exp_1.2/gt_output/gt_bur_5362_4875790905.wav"
# Out:
# /home/lawun330/.cache/torch/hub/NVIDIA_DeepLearningExamples_torchhub/PyTorch/Classification/ConvNets/image_classification/models/common.py:13: UserWarning: pytorch_quantization module not found, quantization will not be available
#   warnings.warn(
# /home/lawun330/.cache/torch/hub/NVIDIA_DeepLearningExamples_torchhub/PyTorch/Classification/ConvNets/image_classification/models/efficientnet.py:17: UserWarning: pytorch_quantization module not found, quantization will not be available
#   warnings.warn(
# /home/lawun330/anaconda3/envs/lu_aief_asr_tts_env/lib/python3.12/site-packages/torch/nn/utils/weight_norm.py:145: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)
# HiFi-GAN: Removing weight norm.
# 2026-09-24 20:59:19  [INFO    ]  HiFi-GAN loaded ✓  (NVIDIA torch.hub)
# 2026-09-24 20:59:19  [INFO    ]  Found bur_5362_4875790905 in train
# 2026-09-24 20:59:19  [INFO    ]  GT text: ကျွန်တော် ကလည်း ဒိတ်ဒိတ်ကျဲ အောင်မြင်နေတဲ့ မင်းသား မှ မဟုတ်တာလေ
# 2026-09-24 20:59:19  [INFO    ]  GT mel: min=-80.0 max=0.0 mean=-57.5 dB  shape=(522, 80)
# 2026-09-24 20:59:21  [INFO    ]  Mel plot → tts_output/v6_exp_1.2/gt_output/gt_bur_5362_4875790905.png
# 2026-09-24 20:59:21  [INFO    ]  GT audio → tts_output/v6_exp_1.2/gt_output/gt_bur_5362_4875790905.wav  (6.06s)
#
# real	0m6.921s
# user	0m23.362s
# sys	0m0.858s

# %%
import IPython.display as ipd
from IPython.display import Image

GT_PATH = current_dir / "tts_output" / "v6_exp_1.2" / "gt_output"

ipd.display(ipd.Audio(f"{GT_PATH}/gt_bur_5362_4875790905.wav"))
ipd.display(Image(filename=f"{GT_PATH}/gt_bur_5362_4875790905.png"))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### Example Sample 2 - WaveGlow

# %%
# !time python {SRC}/myanmar_tts_transformer_v6.py --stage synth \
  --output_dir "./tts_output/v6_exp_1.2" \
  --gt_sample_id bur_8266_7413365509 \
  --synth_out "./tts_output/v6_exp_1.2/gt_output/gt_bur_8266_7413365509.wav" \
  --vocoder waveglow
# Out:
# /home/lawun330/.cache/torch/hub/NVIDIA_DeepLearningExamples_torchhub/PyTorch/Classification/ConvNets/image_classification/models/common.py:13: UserWarning: pytorch_quantization module not found, quantization will not be available
#   warnings.warn(
# /home/lawun330/.cache/torch/hub/NVIDIA_DeepLearningExamples_torchhub/PyTorch/Classification/ConvNets/image_classification/models/efficientnet.py:17: UserWarning: pytorch_quantization module not found, quantization will not be available
#   warnings.warn(
# /home/lawun330/anaconda3/envs/lu_aief_asr_tts_env/lib/python3.12/site-packages/torch/jit/_script.py:1491: FutureWarning: `torch.jit.script` is deprecated. Please switch to `torch.compile` or `torch.export`.
#   warnings.warn(
# /home/lawun330/anaconda3/envs/lu_aief_asr_tts_env/lib/python3.12/site-packages/torch/nn/utils/weight_norm.py:145: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)
# 2026-09-24 20:59:28  [INFO    ]  WaveGlow loaded ✓  (NVIDIA torch.hub, sigma=0.6)
# 2026-09-24 20:59:28  [INFO    ]  Found bur_8266_7413365509 in train
# 2026-09-24 20:59:28  [INFO    ]  GT text: ဥပမာ မိုးဟေကို ဆိုရင် ဆောင်းဟေကို နာမည် ကို ဆင်တူ ပေးထားတာမျိုး ပေါ့
# 2026-09-24 20:59:28  [INFO    ]  GT mel: min=-80.0 max=0.0 mean=-61.6 dB  shape=(530, 80)
# 2026-09-24 20:59:34  [INFO    ]  Mel plot → tts_output/v6_exp_1.2/gt_output/gt_bur_8266_7413365509.png
# 2026-09-24 20:59:34  [INFO    ]  GT audio → tts_output/v6_exp_1.2/gt_output/gt_bur_8266_7413365509.wav  (6.15s)
#
# real	0m12.754s
# user	0m21.237s
# sys	0m2.342s

# %%
ipd.display(ipd.Audio(f"{GT_PATH}/gt_bur_8266_7413365509.wav"))
ipd.display(Image(filename=f"{GT_PATH}/gt_bur_8266_7413365509.png"))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### Example Sample 3 - Griffin-Lim

# %%
# !time python {SRC}/myanmar_tts_transformer_v6.py --stage synth \
  --output_dir "./tts_output/v6_exp_1.2" \
  --gt_sample_id bur_5932_6467856225 \
  --synth_out "./tts_output/v6_exp_1.2/gt_output/gt_bur_5932_6467856225.wav" \
  --no_neural_vocoder
# Out:
# 2026-09-24 20:59:51  [INFO    ]  Vocoder: Griffin-Lim
# 2026-09-24 20:59:51  [INFO    ]  Found bur_5932_6467856225 in train
# 2026-09-24 20:59:51  [INFO    ]  GT text: ရုပ်ရှင်ကားကြီးတွေ ရိုက်ရင် ဖလင် က တအား ကုန်တယ်
# 2026-09-24 20:59:51  [INFO    ]  GT mel: min=-80.0 max=0.0 mean=-52.6 dB  shape=(317, 80)
# 2026-09-24 20:59:56  [INFO    ]  Mel plot → tts_output/v6_exp_1.2/gt_output/gt_bur_5932_6467856225.png
# 2026-09-24 20:59:56  [INFO    ]  GT audio → tts_output/v6_exp_1.2/gt_output/gt_bur_5932_6467856225.wav  (3.67s)
#
# real	0m7.630s
# user	0m12.634s
# sys	0m0.566s

# %%
ipd.display(ipd.Audio(f"{GT_PATH}/gt_bur_5932_6467856225.wav"))
ipd.display(Image(filename=f"{GT_PATH}/gt_bur_5932_6467856225.png"))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Testing (Prediction)

# %% [markdown]
# ### Longer Prediction

# %%
# !time python {SRC}/myanmar_tts_transformer_v6.py --stage synth \
  --output_dir "./tts_output/v6_exp_1.2" \
  --synth_text "ကျွန်တော် ကလည်း ဒိတ်ဒိတ်ကျဲ အောင်မြင်နေတဲ့ မင်းသား မှ မဟုတ်တာလေ" \
  --synth_out "./tts_output/v6_exp_1.2/gt_output/gt_bur_5362_4875790905_synthesized.wav" \
  --gt_compare
# Out:
# /home/lawun330/.cache/torch/hub/NVIDIA_DeepLearningExamples_torchhub/PyTorch/Classification/ConvNets/image_classification/models/common.py:13: UserWarning: pytorch_quantization module not found, quantization will not be available
#   warnings.warn(
# /home/lawun330/.cache/torch/hub/NVIDIA_DeepLearningExamples_torchhub/PyTorch/Classification/ConvNets/image_classification/models/efficientnet.py:17: UserWarning: pytorch_quantization module not found, quantization will not be available
#   warnings.warn(
# /home/lawun330/anaconda3/envs/lu_aief_asr_tts_env/lib/python3.12/site-packages/torch/nn/utils/weight_norm.py:145: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)
# HiFi-GAN: Removing weight norm.
# 2026-09-24 21:00:07  [INFO    ]  HiFi-GAN loaded ✓  (NVIDIA torch.hub)
# 2026-09-24 21:00:09  [INFO    ]  Loaded TransformerTTS: epoch=48 dev=0.3077
# 2026-09-24 21:00:09  [INFO    ]  Synthesizing: 'ကျွန်တော် ကလည်း ဒိတ်ဒိတ်ကျဲ အောင်မြင်နေတဲ့ မင်းသား မှ မဟုတ်တာလေ'
# 2026-09-24 21:00:09  [INFO    ]    length   : 65 tokens × 7.3 fpc ≈ 472 frames  (floor=236, cap=1200)
# 2026-09-24 21:00:09  [INFO    ]    stop_thresh=0.65
# 2026-09-24 21:00:13  [INFO    ]  Attention plot → tts_output/v6_exp_1.2/gt_output/gt_bur_5362_4875790905_synthesized_attn.png  (diag_score=0.258; >0.3 usually OK)
# 2026-09-24 21:00:13  [INFO    ]    mel_norm : min=-1.182  max=-0.071  mean=-0.953
# 2026-09-24 21:00:13  [INFO    ]    mel_db   : min=-80.0  max=-42.9  mean=-77.7 dB
# 2026-09-24 21:00:13  [INFO    ]    shape    : (237, 80)  (2.75s at default hop/sr)
# 2026-09-24 21:00:13  [WARNING ]    ⚠ mel_db max=-42.9 dB. Model may need more epochs (try 200+).
# 2026-09-24 21:00:13  [INFO    ]  Acoustic model: 4238 ms
# 2026-09-24 21:00:13  [INFO    ]  Mel plot → tts_output/v6_exp_1.2/gt_output/gt_bur_5362_4875790905_synthesized.png
# 2026-09-24 21:00:14  [INFO    ]  Vocoder: 677 ms  |  Audio → tts_output/v6_exp_1.2/gt_output/gt_bur_5362_4875790905_synthesized.wav  (2.75s)
# 2026-09-24 21:00:14  [INFO    ]  Found text match in train
# 2026-09-24 21:00:15  [INFO    ]  GT comparison → tts_output/v6_exp_1.2/gt_output/gt_bur_5362_4875790905_synthesized_GT.wav
# 2026-09-24 21:00:16  [INFO    ]  Comparison plot → tts_output/v6_exp_1.2/gt_output/gt_bur_5362_4875790905_synthesized_compare.png
#
# real	0m13.896s
# user	0m36.374s
# sys	0m1.742s

# %%
ipd.display(ipd.Audio(f"{GT_PATH}/gt_bur_5362_4875790905_synthesized_GT.wav"))
ipd.display(ipd.Audio(f"{GT_PATH}/gt_bur_5362_4875790905_synthesized.wav"))
ipd.display(Image(filename=f"{GT_PATH}/gt_bur_5362_4875790905_synthesized_compare.png"))
ipd.display(Image(filename=f"{GT_PATH}/gt_bur_5362_4875790905_synthesized_attn.png"))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### Shorter Prediction

# %%
# !time python {SRC}/myanmar_tts_transformer_v6.py --stage synth \
  --output_dir "./tts_output/v6_exp_1.2" \
  --synth_text "ရုပ်ရှင်ကားကြီးတွေ" \
  --synth_out "./tts_output/v6_exp_1.2/gt_output/gt_custom_synthesized.wav" \
  --gt_compare
# Out:
# /home/lawun330/.cache/torch/hub/NVIDIA_DeepLearningExamples_torchhub/PyTorch/Classification/ConvNets/image_classification/models/common.py:13: UserWarning: pytorch_quantization module not found, quantization will not be available
#   warnings.warn(
# /home/lawun330/.cache/torch/hub/NVIDIA_DeepLearningExamples_torchhub/PyTorch/Classification/ConvNets/image_classification/models/efficientnet.py:17: UserWarning: pytorch_quantization module not found, quantization will not be available
#   warnings.warn(
# /home/lawun330/anaconda3/envs/lu_aief_asr_tts_env/lib/python3.12/site-packages/torch/nn/utils/weight_norm.py:145: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)
# HiFi-GAN: Removing weight norm.
# 2026-09-24 21:26:46  [INFO    ]  HiFi-GAN loaded ✓  (NVIDIA torch.hub)
# 2026-09-24 21:26:47  [INFO    ]  Loaded TransformerTTS: epoch=48 dev=0.3077
# 2026-09-24 21:26:47  [INFO    ]  Synthesizing: 'ရုပ်ရှင်ကားကြီးတွေ'
# 2026-09-24 21:26:47  [INFO    ]    length   : 20 tokens × 7.3 fpc ≈ 145 frames  (floor=72, cap=382)
# 2026-09-24 21:26:47  [INFO    ]    stop_thresh=0.65
# 2026-09-24 21:26:49  [INFO    ]  Attention plot → tts_output/v6_exp_1.2/gt_output/gt_custom_synthesized_attn.png  (diag_score=0.372; >0.3 usually OK)
# 2026-09-24 21:26:49  [INFO    ]    mel_norm : min=-1.117  max=-0.063  mean=-0.961
# 2026-09-24 21:26:49  [INFO    ]    mel_db   : min=-80.0  max=-42.5  mean=-78.1 dB
# 2026-09-24 21:26:49  [INFO    ]    shape    : (73, 80)  (0.85s at default hop/sr)
# 2026-09-24 21:26:49  [WARNING ]    ⚠ mel_db max=-42.5 dB. Model may need more epochs (try 200+).
# 2026-09-24 21:26:49  [INFO    ]  Acoustic model: 1711 ms
# 2026-09-24 21:26:49  [INFO    ]  Mel plot → tts_output/v6_exp_1.2/gt_output/gt_custom_synthesized.png
# 2026-09-24 21:26:49  [INFO    ]  Vocoder: 196 ms  |  Audio → tts_output/v6_exp_1.2/gt_output/gt_custom_synthesized.wav  (0.85s)
# 2026-09-24 21:26:49  [INFO    ]  No exact GT match found.
#
# real	0m7.334s
# user	0m16.661s
# sys	0m1.063s

# %%
ipd.display(ipd.Audio(f"{GT_PATH}/gt_custom_synthesized.wav"))
ipd.display(Image(filename=f"{GT_PATH}/gt_custom_synthesized_attn.png"))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
