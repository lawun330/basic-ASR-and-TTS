# %% [markdown]
# # TTS Tutorial Remake with SLR80 Dataset
#
# ## Original
# - **Prepared by:** Ye Kyaw Thu, Language Understanding Lab., Myanmar
# - **Last Updated Date:** 20 June 2026
# - **Reason:** *For AI Engineering (Fundamental) class students*
#
# ## Remake: Experiment Version 1.3
# This remake follows the same tutorial flow with v6, which adds HiFi-GAN/WaveGlow vocoders, scheduled sampling, softer stop, and attention plots on top of the v5 TransformerTTS core.

# %% [markdown]
# ## Setup

# %%
from pathlib import Path

current_dir = Path.cwd()
SCRIPTS = current_dir / "scripts"
SRC = current_dir / "src"

# %% [markdown]
# ## Download Dataset: SLR80

# %%
# skip if data already downloaded
# !time {SCRIPTS}/download_dataset.sh

# %%
# !tree ./data/ | head -n 10
# Out:
# ./data/
# └── slr80
#     ├── bur_0366_0045318711.wav
#     ├── bur_0366_0096392289.wav
#     ├── bur_0366_0178258874.wav
#     ├── bur_0366_0235517782.wav
#     ├── bur_0366_0432235369.wav
#     ├── bur_0366_0445549145.wav
#     ├── bur_0366_0446483510.wav
#     ├── bur_0366_0469985799.wav

# %%
# !head ./data/slr80/line_index_female.tsv
# Out:
# bur_7865_1250917969	ပြီးတော့ တရုတ် နဲ့လည်း ချစ်ကြည်ရင်းနှီးတဲ့ ဆက်ဆံရေး ရှိတယ်
# bur_8698_6883351313	အဲ့ဒီ ဝေဖန်မှုတွေ နဲ့ ပတ်သက် လို့ ဘယ်လို တုံ့ပြန်ချင်ပါသလဲ
# bur_3260_8853590661	မမီ မွေးဖွားနေတဲ့ အချိန် မှာတော့ ဘုရား ဂုဏ်တော် ကိုပဲ တောက်လျှောက် ရွတ်နေခဲ့ပါတယ်
# bur_2446_1980151079	ခင်ဦးသာ နှင့် နန်းလွင်နှင်းပွင့် ပူးပေါင်း ရေးသားသည်
# bur_5189_8958061789	ကြည့်ရသည်မှာ မြန်မာ နိုင်ငံ တွင် သူ့ အတွက် ခိုလှုံရာ တခု တွေ့ခဲ့ပုံ ရပါသည်
# bur_6884_6350507293	မမဖွေးဖွေး နဲ့ တွေ့ရ တော့ တအား ပျော်တယ် လို့ ပြောပါတယ်
# bur_5362_7563127136	အထူးသဖြင့် နိုင်ငံရေး လောက ကို စုစည်းနိုင်ခဲ့သည် ဟု ဆိုနိုင်ပါသည်
# bur_7543_6156096513	ကဖင်း မပါဝင်သော ကော်ဖီ သောက်ပါ
# bur_8266_0671510151	ကောလင်း မြို့နယ် ရေကြီးတာ က ဆည်ကျိုး လို့ မဟုတ်ဘူး
# bur_6118_8081481703	ကျွန်မ အလုပ် ကို လေးလေးစားစား လုပ်ပါတယ်

# %%
# !head ./data/slr80/line_index.tsv
# Out:
# bur_7865_1250917969	ပြီးတော့ တရုတ် နဲ့လည်း ချစ်ကြည်ရင်းနှီးတဲ့ ဆက်ဆံရေး ရှိတယ်
# bur_8698_6883351313	အဲ့ဒီ ဝေဖန်မှုတွေ နဲ့ ပတ်သက် လို့ ဘယ်လို တုံ့ပြန်ချင်ပါသလဲ
# bur_3260_8853590661	မမီ မွေးဖွားနေတဲ့ အချိန် မှာတော့ ဘုရား ဂုဏ်တော် ကိုပဲ တောက်လျှောက် ရွတ်နေခဲ့ပါတယ်
# bur_2446_1980151079	ခင်ဦးသာ နှင့် နန်းလွင်နှင်းပွင့် ပူးပေါင်း ရေးသားသည်
# bur_5189_8958061789	ကြည့်ရသည်မှာ မြန်မာ နိုင်ငံ တွင် သူ့ အတွက် ခိုလှုံရာ တခု တွေ့ခဲ့ပုံ ရပါသည်
# bur_6884_6350507293	မမဖွေးဖွေး နဲ့ တွေ့ရ တော့ တအား ပျော်တယ် လို့ ပြောပါတယ်
# bur_5362_7563127136	အထူးသဖြင့် နိုင်ငံရေး လောက ကို စုစည်းနိုင်ခဲ့သည် ဟု ဆိုနိုင်ပါသည်
# bur_7543_6156096513	ကဖင်း မပါဝင်သော ကော်ဖီ သောက်ပါ
# bur_8266_0671510151	ကောလင်း မြို့နယ် ရေကြီးတာ က ဆည်ကျိုး လို့ မဟုတ်ဘူး
# bur_6118_8081481703	ကျွန်မ အလုပ် ကို လေးလေးစားစား လုပ်ပါတယ်

# %% [markdown]
# ## Prepare Dataset: SLR80
#
# Original:
# ```Python
# !time python {SRC}/myanmar_tts_transformer.py --stage prep \
#   --data_dir ./data/slr80 \
#   --output_dir ./tts_output
# ```
#
# NAR version:
# ```Python
# !time python {SRC}/myanmar_tts_transformer_nar.py --stage prep \
#   --data_dir ./data/slr80 \
#   --output_dir ./tts_output/nar_version
# ```

# %%
# !time python {SRC}/myanmar_tts_transformer_v6.py --stage prep \
  --data_dir ./data/slr80 \
  --output_dir "./tts_output/v6_exp_1.3"
# Out:
# 2026-09-24 21:46:58  [INFO    ]  Found 2530 audio files.
# 2026-09-24 21:46:58  [INFO    ]  Vocabulary: 66 characters
# 2026-09-24 21:46:58  [INFO    ]  Computing mel spectrograms ...
# 2026-09-24 21:47:06  [INFO    ]    500/2530 ...
# 2026-09-24 21:47:16  [INFO    ]    1000/2530 ...
# 2026-09-24 21:47:24  [INFO    ]    1500/2530 ...
# 2026-09-24 21:47:33  [INFO    ]    2000/2530 ...
# 2026-09-24 21:47:43  [INFO    ]    2500/2530 ...
# 2026-09-24 21:47:43  [INFO    ]  Valid: 2530 | Skipped: 0
# 2026-09-24 21:47:43  [INFO    ]  Mel norm check: min=-1.000 max=1.000 mean=-0.481
# 2026-09-24 21:47:43  [INFO    ]  Mel frames : mean=504 ± 150
# 2026-09-24 21:47:43  [INFO    ]  Frames/char: mean=7.3 ± 1.6
# 2026-09-24 21:47:44  [INFO    ]    train: 2024
# 2026-09-24 21:47:44  [INFO    ]    dev: 253
# 2026-09-24 21:47:44  [INFO    ]    test: 253
# 2026-09-24 21:47:44  [INFO    ]  Data preparation complete ✓
#
# real	0m47.989s
# user	8m17.734s
# sys	0m2.004s

# %% [markdown]
# ## Model Training
#
# Original:
# ```Python
# !time python {SRC}/myanmar_tts_transformer.py --stage train \
#   --output_dir ./tts_output \
#   --epochs 300
# ```
#
# NAR version:
# ```Python
# !time python {SRC}/myanmar_tts_transformer_nar.py --stage train \
#   --output_dir ./tts_output/nar_version \
#   --epochs 300 \
#   --batch_size 8 \
#   --dur_loss_weight 1.0
# ```
#
# v6 experiment 1.0 version:
# ```python
# !time python {SRC}/myanmar_tts_transformer_v6.py --stage train \
#   --output_dir ./tts_output/v6 \
#   --epochs 300 \
#   --batch_size 8 \
#   --ga_weight 1.0 --ga_g 0.2 \
#   --ss_start_epoch 50 \
#   --ss_max_prob 0.5
# ```
#
# v6 experiment 1.1 version:
# ```python
# !time python {SRC}/myanmar_tts_transformer_v6.py --stage train \
#   --output_dir "./tts_output/v6_exp_1.1" \
#   --epochs 130 \
#   --batch_size 8 \
#   --ga_weight 3.0 --ga_g 0.15 \
#   --ss_start_epoch 20 \
#   --ss_max_prob 0.8
# ```
#
# v6 experiment 1.2 version:
# ```python
# !time python {SRC}/myanmar_tts_transformer_v6.py --stage train \
#   --output_dir "./tts_output/v6_exp_1.2" \
#   --epochs 50 \
#   --batch_size 8 \
#   --ga_weight 5.0 --ga_g 0.1 \
#   --ss_start_epoch 10 \
#   --ss_max_prob 0.8
# ```

# %%
# !time python {SRC}/myanmar_tts_transformer_v6.py --stage train \
  --output_dir "./tts_output/v6_exp_1.3" \
  --epochs 50 \
  --batch_size 8 \
  --ga_weight 8.0 --ga_g 0.08 \
  --ss_start_epoch 10 \
  --ss_max_prob 0.8
# Out:
# 2026-09-24 21:50:18  [INFO    ]  Vocab:66  Train:2024  Dev:253
# 2026-09-24 21:50:18  [INFO    ]  Device: cuda
# 2026-09-24 21:50:19  [INFO    ]  TransformerTTS parameters: 45,399,617
# 2026-09-24 21:50:22  [INFO    ]  Training 50 epochs (warmup=20, lr=1.0e-03)
# 2026-09-24 21:50:22  [INFO    ]  Architecture: TransformerTTS v6 + Guided Attention + HiFi-GAN
# 2026-09-24 21:50:22  [INFO    ]    ga_weight=8.0  ga_g=0.08  stop_loss_weight=0.1
# 2026-09-24 21:50:22  [INFO    ]    scheduled sampling: start_epoch=10  max_prob=0.8
# 2026-09-24 21:50:22  [INFO    ]  Expected: dig should fall toward ~0.2–0.4 like v5 if GA is healthy.
# 2026-09-24 21:53:40  [INFO    ]  Epoch    1/50 | train=1.7250  dev=1.2291 | lr=1.00e-04  ss=0.00
# 2026-09-24 21:53:40  [INFO    ]    ✓ Best model saved (dev=1.2291)
# 2026-09-24 21:56:58  [INFO    ]  Epoch    2/50 | train=1.1896  dev=0.8436 | lr=1.50e-04  ss=0.00
# 2026-09-24 21:56:59  [INFO    ]    ✓ Best model saved (dev=0.8436)
# 2026-09-24 22:00:17  [INFO    ]  Epoch    3/50 | train=0.9798  dev=0.7548 | lr=2.00e-04  ss=0.00
# 2026-09-24 22:00:18  [INFO    ]    ✓ Best model saved (dev=0.7548)
# 2026-09-24 22:03:37  [INFO    ]  Epoch    4/50 | train=0.8354  dev=0.7635 | lr=2.50e-04  ss=0.00
# 2026-09-24 22:06:57  [INFO    ]  Epoch    5/50 | train=0.7770  dev=0.6214 | lr=3.00e-04  ss=0.00
# 2026-09-24 22:06:59  [INFO    ]    ✓ Best model saved (dev=0.6214)
# 2026-09-24 22:10:16  [INFO    ]  Epoch    6/50 | train=0.6918  dev=0.5832 | lr=3.50e-04  ss=0.00
# 2026-09-24 22:10:17  [INFO    ]    ✓ Best model saved (dev=0.5832)
# 2026-09-24 22:13:36  [INFO    ]  Epoch    7/50 | train=0.6332  dev=0.5482 | lr=4.00e-04  ss=0.00
# 2026-09-24 22:13:37  [INFO    ]    ✓ Best model saved (dev=0.5482)
# 2026-09-24 22:16:56  [INFO    ]  Epoch    8/50 | train=0.5938  dev=0.5013 | lr=4.50e-04  ss=0.00
# 2026-09-24 22:17:03  [INFO    ]    ✓ Best model saved (dev=0.5013)
# 2026-09-24 22:20:19  [INFO    ]  Epoch    9/50 | train=0.5341  dev=0.4890 | lr=5.00e-04  ss=0.00
# 2026-09-24 22:20:27  [INFO    ]    ✓ Best model saved (dev=0.4890)
# 2026-09-24 22:24:44  [INFO    ]  Epoch   10/50 | train=0.4979  dev=0.4756 | lr=5.50e-04  ss=0.02
# 2026-09-24 22:24:49  [INFO    ]    ✓ Best model saved (dev=0.4756)
# 2026-09-24 22:29:07  [INFO    ]  Epoch   11/50 | train=0.4748  dev=0.4492 | lr=6.00e-04  ss=0.04
# 2026-09-24 22:29:11  [INFO    ]    ✓ Best model saved (dev=0.4492)
# 2026-09-24 22:33:26  [INFO    ]  Epoch   12/50 | train=0.4775  dev=0.4820 | lr=6.50e-04  ss=0.06
# 2026-09-24 22:37:42  [INFO    ]  Epoch   13/50 | train=0.4662  dev=0.4303 | lr=7.00e-04  ss=0.08
# 2026-09-24 22:37:49  [INFO    ]    ✓ Best model saved (dev=0.4303)
# 2026-09-24 22:42:07  [INFO    ]  Epoch   14/50 | train=0.4448  dev=0.4193 | lr=7.50e-04  ss=0.10
# 2026-09-24 22:42:08  [INFO    ]    ✓ Best model saved (dev=0.4193)
# 2026-09-24 22:46:26  [INFO    ]  Epoch   15/50 | train=0.4309  dev=0.4160 | lr=8.00e-04  ss=0.12
# 2026-09-24 22:46:27  [INFO    ]    ✓ Best model saved (dev=0.4160)
# 2026-09-24 22:50:44  [INFO    ]  Epoch   16/50 | train=0.4212  dev=0.4060 | lr=8.50e-04  ss=0.14
# 2026-09-24 22:50:45  [INFO    ]    ✓ Best model saved (dev=0.4060)
# 2026-09-24 22:55:03  [INFO    ]  Epoch   17/50 | train=0.4167  dev=0.4010 | lr=9.00e-04  ss=0.16
# 2026-09-24 22:55:04  [INFO    ]    ✓ Best model saved (dev=0.4010)
# 2026-09-24 22:59:20  [INFO    ]  Epoch   18/50 | train=0.4135  dev=0.3928 | lr=9.50e-04  ss=0.18
# 2026-09-24 22:59:21  [INFO    ]    ✓ Best model saved (dev=0.3928)
# 2026-09-24 23:03:37  [INFO    ]  Epoch   19/50 | train=0.4078  dev=0.3898 | lr=1.00e-03  ss=0.20
# 2026-09-24 23:03:38  [INFO    ]    ✓ Best model saved (dev=0.3898)
# 2026-09-24 23:07:56  [INFO    ]  Epoch   20/50 | train=0.4093  dev=0.3890 | lr=1.00e-03  ss=0.22
# 2026-09-24 23:07:57  [INFO    ]    ✓ Best model saved (dev=0.3890)
# 2026-09-24 23:12:15  [INFO    ]  Epoch   21/50 | train=0.4030  dev=0.3793 | lr=9.97e-04  ss=0.24
# 2026-09-24 23:12:20  [INFO    ]    ✓ Best model saved (dev=0.3793)
# 2026-09-24 23:16:39  [INFO    ]  Epoch   22/50 | train=0.4004  dev=0.3774 | lr=9.90e-04  ss=0.26
# 2026-09-24 23:16:45  [INFO    ]    ✓ Best model saved (dev=0.3774)
# 2026-09-24 23:21:04  [INFO    ]  Epoch   23/50 | train=0.3917  dev=0.3784 | lr=9.77e-04  ss=0.28
# 2026-09-24 23:25:24  [INFO    ]  Epoch   24/50 | train=0.3903  dev=0.3598 | lr=9.59e-04  ss=0.30
# 2026-09-24 23:25:33  [INFO    ]    ✓ Best model saved (dev=0.3598)
# 2026-09-24 23:29:52  [INFO    ]  Epoch   25/50 | train=0.3864  dev=0.3670 | lr=9.36e-04  ss=0.32
# 2026-09-24 23:34:10  [INFO    ]  Epoch   26/50 | train=0.3860  dev=0.3637 | lr=9.09e-04  ss=0.34
# 2026-09-24 23:38:31  [INFO    ]  Epoch   27/50 | train=0.3782  dev=0.3626 | lr=8.78e-04  ss=0.36
# 2026-09-24 23:42:49  [INFO    ]  Epoch   28/50 | train=0.3779  dev=0.3469 | lr=8.43e-04  ss=0.38
# 2026-09-24 23:42:56  [INFO    ]    ✓ Best model saved (dev=0.3469)
# 2026-09-24 23:47:15  [INFO    ]  Epoch   29/50 | train=0.3713  dev=0.3526 | lr=8.04e-04  ss=0.40
# 2026-09-24 23:51:34  [INFO    ]  Epoch   30/50 | train=0.3680  dev=0.3497 | lr=7.62e-04  ss=0.42
# 2026-09-24 23:55:53  [INFO    ]  Epoch   31/50 | train=0.3651  dev=0.3434 | lr=7.18e-04  ss=0.44
# 2026-09-24 23:55:54  [INFO    ]    ✓ Best model saved (dev=0.3434)
# 2026-09-25 00:00:10  [INFO    ]  Epoch   32/50 | train=0.3601  dev=0.3412 | lr=6.72e-04  ss=0.46
# 2026-09-25 00:00:11  [INFO    ]    ✓ Best model saved (dev=0.3412)
# 2026-09-25 00:04:27  [INFO    ]  Epoch   33/50 | train=0.3594  dev=0.3378 | lr=6.24e-04  ss=0.48
# 2026-09-25 00:04:28  [INFO    ]    ✓ Best model saved (dev=0.3378)
# 2026-09-25 00:08:45  [INFO    ]  Epoch   34/50 | train=0.3555  dev=0.3384 | lr=5.75e-04  ss=0.50
# 2026-09-25 00:13:00  [INFO    ]  Epoch   35/50 | train=0.3512  dev=0.3342 | lr=5.25e-04  ss=0.52
# 2026-09-25 00:13:01  [INFO    ]    ✓ Best model saved (dev=0.3342)
# 2026-09-25 00:17:20  [INFO    ]  Epoch   36/50 | train=0.3497  dev=0.3386 | lr=4.75e-04  ss=0.54
# 2026-09-25 00:21:34  [INFO    ]  Epoch   37/50 | train=0.3480  dev=0.3360 | lr=4.26e-04  ss=0.56
# 2026-09-25 00:25:51  [INFO    ]  Epoch   38/50 | train=0.3439  dev=0.3329 | lr=3.78e-04  ss=0.58
# 2026-09-25 00:25:52  [INFO    ]    ✓ Best model saved (dev=0.3329)
# 2026-09-25 00:30:10  [INFO    ]  Epoch   39/50 | train=0.3416  dev=0.3272 | lr=3.32e-04  ss=0.60
# 2026-09-25 00:30:11  [INFO    ]    ✓ Best model saved (dev=0.3272)
# 2026-09-25 00:34:29  [INFO    ]  Epoch   40/50 | train=0.3395  dev=0.3283 | lr=2.88e-04  ss=0.62
# 2026-09-25 00:38:49  [INFO    ]  Epoch   41/50 | train=0.3375  dev=0.3278 | lr=2.46e-04  ss=0.64
# 2026-09-25 00:43:07  [INFO    ]  Epoch   42/50 | train=0.3353  dev=0.3250 | lr=2.07e-04  ss=0.66
# 2026-09-25 00:43:08  [INFO    ]    ✓ Best model saved (dev=0.3250)
# 2026-09-25 00:47:29  [INFO    ]  Epoch   43/50 | train=0.3341  dev=0.3254 | lr=1.72e-04  ss=0.68
# 2026-09-25 00:51:47  [INFO    ]  Epoch   44/50 | train=0.3327  dev=0.3243 | lr=1.41e-04  ss=0.70
# 2026-09-25 00:51:53  [INFO    ]    ✓ Best model saved (dev=0.3243)
# 2026-09-25 00:56:12  [INFO    ]  Epoch   45/50 | train=0.3314  dev=0.3240 | lr=1.14e-04  ss=0.72
# 2026-09-25 00:56:17  [INFO    ]    ✓ Best model saved (dev=0.3240)
# 2026-09-25 01:00:34  [INFO    ]  Epoch   46/50 | train=0.3314  dev=0.3239 | lr=9.11e-05  ss=0.74
# 2026-09-25 01:00:41  [INFO    ]    ✓ Best model saved (dev=0.3239)
# 2026-09-25 01:04:57  [INFO    ]  Epoch   47/50 | train=0.3304  dev=0.3231 | lr=7.32e-05  ss=0.76
# 2026-09-25 01:05:04  [INFO    ]    ✓ Best model saved (dev=0.3231)
# 2026-09-25 01:09:22  [INFO    ]  Epoch   48/50 | train=0.3299  dev=0.3234 | lr=6.04e-05  ss=0.78
# 2026-09-25 01:13:39  [INFO    ]  Epoch   49/50 | train=0.3299  dev=0.3233 | lr=5.26e-05  ss=0.80
# 2026-09-25 01:17:59  [INFO    ]  Epoch   50/50 | train=0.3290  dev=0.3236 | lr=5.00e-05  ss=0.80
# 2026-09-25 01:17:59  [INFO    ]  Training done. Best dev: 0.3231
#
# real	207m43.415s
# user	206m46.439s
# sys	1m22.275s

# %% [markdown]
# ## Check Samples

# %%
# !time python {SRC}/myanmar_tts_transformer_v6.py --stage synth \
  --output_dir "./tts_output/v6_exp_1.3" \
  --list_samples
# Out:
# /home/lawun330/.cache/torch/hub/NVIDIA_DeepLearningExamples_torchhub/PyTorch/Classification/ConvNets/image_classification/models/common.py:13: UserWarning: pytorch_quantization module not found, quantization will not be available
#   warnings.warn(
# /home/lawun330/.cache/torch/hub/NVIDIA_DeepLearningExamples_torchhub/PyTorch/Classification/ConvNets/image_classification/models/efficientnet.py:17: UserWarning: pytorch_quantization module not found, quantization will not be available
#   warnings.warn(
# /home/lawun330/anaconda3/envs/lu_aief_asr_tts_env/lib/python3.12/site-packages/torch/nn/utils/weight_norm.py:145: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)
# HiFi-GAN: Removing weight norm.
# 2026-09-25 01:18:04  [INFO    ]  HiFi-GAN loaded ✓  (NVIDIA torch.hub)
# 2026-09-25 01:18:04  [INFO    ]  Sample IDs (first 20):
# 2026-09-25 01:18:04  [INFO    ]    bur_8266_7413365509               ဥပမာ မိုးဟေကို ဆိုရင် ဆောင်းဟေကို နာမည် ကို ဆင်တူ
# 2026-09-25 01:18:04  [INFO    ]    bur_7865_2573585785               ဒါပေမဲ့ ဒီ ကျောက် က ရာသက်ပန် မကုန်အောင် ထွက်နေမှာ
# 2026-09-25 01:18:04  [INFO    ]    bur_5189_3215659791               ကိုကျော်သူ မမေသန်းနု ဒေါ်အေးအေးသင်းတို့ ပါတယ်
# 2026-09-25 01:18:04  [INFO    ]    bur_0644_5980380162               အမှန်တော့ မှတ်တမ်း ကို ဖလင် နဲ့ ရိုက် ပြီး ပြတဲ့ ရ
# 2026-09-25 01:18:04  [INFO    ]    bur_5932_9903725735               ကျနော် က ကျော်ထွဋ်ဆွေတို့ ဂျောက်ဂျက်တို့ နဲ့တော့ သ
# 2026-09-25 01:18:04  [INFO    ]    bur_5932_6467856225               ရုပ်ရှင်ကားကြီးတွေ ရိုက်ရင် ဖလင် က တအား ကုန်တယ်
# 2026-09-25 01:18:04  [INFO    ]    bur_7543_1589569333               ကာတွန်း ရှိန်အောင် ကို ပုသိမ်မြို့ မှာ အဖ ဦးမောင်က
# 2026-09-25 01:18:04  [INFO    ]    bur_9762_6350280557               ကြည့်ချင်တယ် ဆိုရင်လည်း ခရီးစဉ် တခါတည်း ထည့် ဆွဲထာ
# 2026-09-25 01:18:04  [INFO    ]    bur_5903_4827254748               အခု က ဖုန်း တစ်လုံး ပဲ ထားရတော့တယ် ဟု ဆိုသည်
# 2026-09-25 01:18:04  [INFO    ]    bur_3260_5647990176               ကိုယ် ကလည်း အချိန် မပေးနိုင်ဘူး ဆိုတော့ ဆရာဝန်ကြီး
# 2026-09-25 01:18:04  [INFO    ]    bur_5362_4730425798               ခေတ်မှီချင်သူတွေ ကတော့ ရေခဲမုန့် ကျွေးကြတာပေါ့
# 2026-09-25 01:18:04  [INFO    ]    bur_8266_3739445651               ကဲ အခု တော့ ဘယ့်နှယ့် ရှိစ
# 2026-09-25 01:18:04  [INFO    ]    bur_9135_9365873650               အထက် မြန်မာပြည် မန္တလေး မြို့ ၌လည်း ဘတ်စကတ်ဘော ကလပ
# 2026-09-25 01:18:04  [INFO    ]    bur_5932_0137380639               အရင် တုန်းကတော့ ဒီ ကိစ္စ ကို အားလုံး လေးငါးခြောက်ယ
# 2026-09-25 01:18:04  [INFO    ]    bur_8698_8976831996               မင်း အမေ ကို ကောင်းကောင်း ဆော်သွား လို့ မင်း ထွက်လ
# 2026-09-25 01:18:04  [INFO    ]    bur_0366_2701213104               ကမ္ဘာအနှံ့ မှ သတင်း အချက်အလက်တွေ ကို သိနိုင်သည်
# 2026-09-25 01:18:04  [INFO    ]    bur_0644_2661360424               ဆိုနီ ကရော ဘယ်လိုတွေ ချပြမလဲ လေ့လာကြည့်ရအောင်
# 2026-09-25 01:18:04  [INFO    ]    bur_7712_5029179191               ကမ္မောဇ ဘောလုံး အသင်း က ဥက္ကဌ ဦးခင်မောင်လတ် က အရင်
# 2026-09-25 01:18:04  [INFO    ]    bur_5362_4875790905               ကျွန်တော် ကလည်း ဒိတ်ဒိတ်ကျဲ အောင်မြင်နေတဲ့ မင်းသား
# 2026-09-25 01:18:04  [INFO    ]    bur_3260_2712519099               ကျနော် က ရိက္ခာ ယူခိုင်း တုန်း ထွက်ပြေးလာတာပါ
#
# real	0m4.798s
# user	0m15.668s
# sys	0m0.627s

# %% [markdown]
# ## Check Vocoders
#
# Install Myanmar font via:
# ```bash
# sudo apt update
# sudo apt install python3-gi python3-gi-cairo gir1.2-pango-1.0
#
# # alternatively
# sudo apt install fonts-sil-padauk fonts-noto-core
# ```

# %% [markdown]
# ### Example Sample 1 - HiFi-GAN

# %%
# !time python {SRC}/myanmar_tts_transformer_v6.py --stage synth \
  --output_dir "./tts_output/v6_exp_1.3" \
  --gt_sample_id bur_5362_4875790905 \
  --synth_out "./tts_output/v6_exp_1.3/gt_output/gt_bur_5362_4875790905.wav"
# Out:
# /home/lawun330/.cache/torch/hub/NVIDIA_DeepLearningExamples_torchhub/PyTorch/Classification/ConvNets/image_classification/models/common.py:13: UserWarning: pytorch_quantization module not found, quantization will not be available
#   warnings.warn(
# /home/lawun330/.cache/torch/hub/NVIDIA_DeepLearningExamples_torchhub/PyTorch/Classification/ConvNets/image_classification/models/efficientnet.py:17: UserWarning: pytorch_quantization module not found, quantization will not be available
#   warnings.warn(
# /home/lawun330/anaconda3/envs/lu_aief_asr_tts_env/lib/python3.12/site-packages/torch/nn/utils/weight_norm.py:145: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)
# HiFi-GAN: Removing weight norm.
# 2026-09-25 01:30:27  [INFO    ]  HiFi-GAN loaded ✓  (NVIDIA torch.hub)
# 2026-09-25 01:30:27  [INFO    ]  Found bur_5362_4875790905 in train
# 2026-09-25 01:30:27  [INFO    ]  GT text: ကျွန်တော် ကလည်း ဒိတ်ဒိတ်ကျဲ အောင်မြင်နေတဲ့ မင်းသား မှ မဟုတ်တာလေ
# 2026-09-25 01:30:27  [INFO    ]  GT mel: min=-80.0 max=0.0 mean=-57.5 dB  shape=(522, 80)
# 2026-09-25 01:30:29  [INFO    ]  Mel plot → tts_output/v6_exp_1.3/gt_output/gt_bur_5362_4875790905.png
# 2026-09-25 01:30:29  [INFO    ]  GT audio → tts_output/v6_exp_1.3/gt_output/gt_bur_5362_4875790905.wav  (6.06s)
#
# real	0m7.021s
# user	0m25.257s
# sys	0m0.760s

# %%
import IPython.display as ipd
from IPython.display import Image

GT_PATH = current_dir / "tts_output" / "v6_exp_1.3" / "gt_output"

ipd.display(ipd.Audio(f"{GT_PATH}/gt_bur_5362_4875790905.wav"))
ipd.display(Image(filename=f"{GT_PATH}/gt_bur_5362_4875790905.png"))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### Example Sample 2 - WaveGlow

# %%
# !time python {SRC}/myanmar_tts_transformer_v6.py --stage synth \
  --output_dir "./tts_output/v6_exp_1.3" \
  --gt_sample_id bur_8266_7413365509 \
  --synth_out "./tts_output/v6_exp_1.3/gt_output/gt_bur_8266_7413365509.wav" \
  --vocoder waveglow
# Out:
# /home/lawun330/.cache/torch/hub/NVIDIA_DeepLearningExamples_torchhub/PyTorch/Classification/ConvNets/image_classification/models/common.py:13: UserWarning: pytorch_quantization module not found, quantization will not be available
#   warnings.warn(
# /home/lawun330/.cache/torch/hub/NVIDIA_DeepLearningExamples_torchhub/PyTorch/Classification/ConvNets/image_classification/models/efficientnet.py:17: UserWarning: pytorch_quantization module not found, quantization will not be available
#   warnings.warn(
# /home/lawun330/anaconda3/envs/lu_aief_asr_tts_env/lib/python3.12/site-packages/torch/jit/_script.py:1491: FutureWarning: `torch.jit.script` is deprecated. Please switch to `torch.compile` or `torch.export`.
#   warnings.warn(
# /home/lawun330/anaconda3/envs/lu_aief_asr_tts_env/lib/python3.12/site-packages/torch/nn/utils/weight_norm.py:145: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)
# 2026-09-25 01:30:37  [INFO    ]  WaveGlow loaded ✓  (NVIDIA torch.hub, sigma=0.6)
# 2026-09-25 01:30:37  [INFO    ]  Found bur_8266_7413365509 in train
# 2026-09-25 01:30:37  [INFO    ]  GT text: ဥပမာ မိုးဟေကို ဆိုရင် ဆောင်းဟေကို နာမည် ကို ဆင်တူ ပေးထားတာမျိုး ပေါ့
# 2026-09-25 01:30:37  [INFO    ]  GT mel: min=-80.0 max=0.0 mean=-61.6 dB  shape=(530, 80)
# 2026-09-25 01:30:41  [INFO    ]  Mel plot → tts_output/v6_exp_1.3/gt_output/gt_bur_8266_7413365509.png
# 2026-09-25 01:30:41  [INFO    ]  GT audio → tts_output/v6_exp_1.3/gt_output/gt_bur_8266_7413365509.wav  (6.15s)
#
# real	0m11.976s
# user	0m19.741s
# sys	0m2.319s

# %%
ipd.display(ipd.Audio(f"{GT_PATH}/gt_bur_8266_7413365509.wav"))
ipd.display(Image(filename=f"{GT_PATH}/gt_bur_8266_7413365509.png"))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### Example Sample 3 - Griffin-Lim

# %%
# !time python {SRC}/myanmar_tts_transformer_v6.py --stage synth \
  --output_dir "./tts_output/v6_exp_1.3" \
  --gt_sample_id bur_5932_6467856225 \
  --synth_out "./tts_output/v6_exp_1.3/gt_output/gt_bur_5932_6467856225.wav" \
  --no_neural_vocoder
# Out:
# 2026-09-25 01:30:44  [INFO    ]  Vocoder: Griffin-Lim
# 2026-09-25 01:30:44  [INFO    ]  Found bur_5932_6467856225 in train
# 2026-09-25 01:30:44  [INFO    ]  GT text: ရုပ်ရှင်ကားကြီးတွေ ရိုက်ရင် ဖလင် က တအား ကုန်တယ်
# 2026-09-25 01:30:44  [INFO    ]  GT mel: min=-80.0 max=0.0 mean=-52.6 dB  shape=(317, 80)
# 2026-09-25 01:30:48  [INFO    ]  Mel plot → tts_output/v6_exp_1.3/gt_output/gt_bur_5932_6467856225.png
# 2026-09-25 01:30:48  [INFO    ]  GT audio → tts_output/v6_exp_1.3/gt_output/gt_bur_5932_6467856225.wav  (3.67s)
#
# real	0m6.496s
# user	0m11.191s
# sys	0m0.445s

# %%
ipd.display(ipd.Audio(f"{GT_PATH}/gt_bur_5932_6467856225.wav"))
ipd.display(Image(filename=f"{GT_PATH}/gt_bur_5932_6467856225.png"))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Testing (Prediction)

# %% [markdown]
# ### Longer Prediction

# %%
# !time python {SRC}/myanmar_tts_transformer_v6.py --stage synth \
  --output_dir "./tts_output/v6_exp_1.3" \
  --synth_text "ကျွန်တော် ကလည်း ဒိတ်ဒိတ်ကျဲ အောင်မြင်နေတဲ့ မင်းသား မှ မဟုတ်တာလေ" \
  --synth_out "./tts_output/v6_exp_1.3/gt_output/gt_bur_5362_4875790905_synthesized.wav" \
  --gt_compare
# Out:
# /home/lawun330/.cache/torch/hub/NVIDIA_DeepLearningExamples_torchhub/PyTorch/Classification/ConvNets/image_classification/models/common.py:13: UserWarning: pytorch_quantization module not found, quantization will not be available
#   warnings.warn(
# /home/lawun330/.cache/torch/hub/NVIDIA_DeepLearningExamples_torchhub/PyTorch/Classification/ConvNets/image_classification/models/efficientnet.py:17: UserWarning: pytorch_quantization module not found, quantization will not be available
#   warnings.warn(
# /home/lawun330/anaconda3/envs/lu_aief_asr_tts_env/lib/python3.12/site-packages/torch/nn/utils/weight_norm.py:145: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)
# HiFi-GAN: Removing weight norm.
# 2026-09-25 01:31:03  [INFO    ]  HiFi-GAN loaded ✓  (NVIDIA torch.hub)
# 2026-09-25 01:31:05  [INFO    ]  Loaded TransformerTTS: epoch=47 dev=0.3231
# 2026-09-25 01:31:05  [INFO    ]  Synthesizing: 'ကျွန်တော် ကလည်း ဒိတ်ဒိတ်ကျဲ အောင်မြင်နေတဲ့ မင်းသား မှ မဟုတ်တာလေ'
# 2026-09-25 01:31:05  [INFO    ]    length   : 65 tokens × 7.3 fpc ≈ 472 frames  (floor=236, cap=1200)
# 2026-09-25 01:31:05  [INFO    ]    stop_thresh=0.65
# 2026-09-25 01:31:09  [INFO    ]  Attention plot → tts_output/v6_exp_1.3/gt_output/gt_bur_5362_4875790905_synthesized_attn.png  (diag_score=0.315; >0.3 usually OK)
# 2026-09-25 01:31:09  [INFO    ]    mel_norm : min=-1.117  max=-0.225  mean=-0.943
# 2026-09-25 01:31:09  [INFO    ]    mel_db   : min=-80.0  max=-49.0  mean=-76.9 dB
# 2026-09-25 01:31:09  [INFO    ]    shape    : (237, 80)  (2.75s at default hop/sr)
# 2026-09-25 01:31:09  [WARNING ]    ⚠ mel_db max=-49.0 dB. Model may need more epochs (try 200+).
# 2026-09-25 01:31:09  [INFO    ]  Acoustic model: 3735 ms
# 2026-09-25 01:31:09  [INFO    ]  Mel plot → tts_output/v6_exp_1.3/gt_output/gt_bur_5362_4875790905_synthesized.png
# 2026-09-25 01:31:10  [INFO    ]  Vocoder: 674 ms  |  Audio → tts_output/v6_exp_1.3/gt_output/gt_bur_5362_4875790905_synthesized.wav  (2.75s)
# 2026-09-25 01:31:10  [INFO    ]  Found text match in train
# 2026-09-25 01:31:11  [INFO    ]  GT comparison → tts_output/v6_exp_1.3/gt_output/gt_bur_5362_4875790905_synthesized_GT.wav
# 2026-09-25 01:31:12  [INFO    ]  Comparison plot → tts_output/v6_exp_1.3/gt_output/gt_bur_5362_4875790905_synthesized_compare.png
#
# real	0m13.276s
# user	0m33.690s
# sys	0m1.716s

# %%
ipd.display(ipd.Audio(f"{GT_PATH}/gt_bur_5362_4875790905_synthesized_GT.wav"))
ipd.display(ipd.Audio(f"{GT_PATH}/gt_bur_5362_4875790905_synthesized.wav"))
ipd.display(Image(filename=f"{GT_PATH}/gt_bur_5362_4875790905_synthesized_compare.png"))
ipd.display(Image(filename=f"{GT_PATH}/gt_bur_5362_4875790905_synthesized_attn.png"))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### Shorter Prediction

# %%
# !time python {SRC}/myanmar_tts_transformer_v6.py --stage synth \
  --output_dir "./tts_output/v6_exp_1.3" \
  --synth_text "ရုပ်ရှင်ကားကြီးတွေ" \
  --synth_out "./tts_output/v6_exp_1.3/gt_output/gt_custom_synthesized.wav" \
  --gt_compare
# Out:
# /home/lawun330/.cache/torch/hub/NVIDIA_DeepLearningExamples_torchhub/PyTorch/Classification/ConvNets/image_classification/models/common.py:13: UserWarning: pytorch_quantization module not found, quantization will not be available
#   warnings.warn(
# /home/lawun330/.cache/torch/hub/NVIDIA_DeepLearningExamples_torchhub/PyTorch/Classification/ConvNets/image_classification/models/efficientnet.py:17: UserWarning: pytorch_quantization module not found, quantization will not be available
#   warnings.warn(
# /home/lawun330/anaconda3/envs/lu_aief_asr_tts_env/lib/python3.12/site-packages/torch/nn/utils/weight_norm.py:145: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)
# HiFi-GAN: Removing weight norm.
# 2026-09-25 01:31:52  [INFO    ]  HiFi-GAN loaded ✓  (NVIDIA torch.hub)
# 2026-09-25 01:31:53  [INFO    ]  Loaded TransformerTTS: epoch=47 dev=0.3231
# 2026-09-25 01:31:53  [INFO    ]  Synthesizing: 'ရုပ်ရှင်ကားကြီးတွေ'
# 2026-09-25 01:31:53  [INFO    ]    length   : 20 tokens × 7.3 fpc ≈ 145 frames  (floor=72, cap=382)
# 2026-09-25 01:31:53  [INFO    ]    stop_thresh=0.65
# 2026-09-25 01:31:55  [INFO    ]  Attention plot → tts_output/v6_exp_1.3/gt_output/gt_custom_synthesized_attn.png  (diag_score=0.341; >0.3 usually OK)
# 2026-09-25 01:31:55  [INFO    ]    mel_norm : min=-1.137  max=-0.125  mean=-0.962
# 2026-09-25 01:31:55  [INFO    ]    mel_db   : min=-80.0  max=-45.0  mean=-77.7 dB
# 2026-09-25 01:31:55  [INFO    ]    shape    : (73, 80)  (0.85s at default hop/sr)
# 2026-09-25 01:31:55  [WARNING ]    ⚠ mel_db max=-45.0 dB. Model may need more epochs (try 200+).
# 2026-09-25 01:31:55  [INFO    ]  Acoustic model: 1780 ms
# 2026-09-25 01:31:55  [INFO    ]  Mel plot → tts_output/v6_exp_1.3/gt_output/gt_custom_synthesized.png
# 2026-09-25 01:31:55  [INFO    ]  Vocoder: 202 ms  |  Audio → tts_output/v6_exp_1.3/gt_output/gt_custom_synthesized.wav  (0.85s)
# 2026-09-25 01:31:55  [INFO    ]  No exact GT match found.
#
# real	0m7.261s
# user	0m16.613s
# sys	0m0.944s

# %%
# ipd.display(ipd.Audio(f"{GT_PATH}/gt_custom_synthesized_GT.wav"))
ipd.display(ipd.Audio(f"{GT_PATH}/gt_custom_synthesized.wav"))
# ipd.display(Image(filename=f"{GT_PATH}/gt_custom_synthesized_compare.png"))
ipd.display(Image(filename=f"{GT_PATH}/gt_custom_synthesized_attn.png"))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
